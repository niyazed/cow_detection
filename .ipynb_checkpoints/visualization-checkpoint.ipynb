# %%
import cv2
import pandas as pd
from PIL import Image

# %%
train_labels = pd.read_csv('data/cow_labels.csv')

# %%
train_labels.tail()
# Out:
#                 filename  width  height class  xmin  ymin  xmax  ymax
# 597  cows_images_100.jpg    360     240   cow    70    14   295   206
# 598   cows_images_43.jpg    360     240   cow   139    68   360   209
# 599   cows_images_43.jpg    360     240   cow     3     1   272   224
# 600   cows_images_87.jpg    360     240   cow   111     9   285   212
# 601   cows_images_87.jpg    360     240   cow     6   126    54   194

# %%
def draw_boxes(image_name):
    selected_value = train_labels[train_labels.filename == image_name]
    img = cv2.imread('raw_images/{}'.format(image_name))
    img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    for index, row in selected_value.iterrows():
        img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
    return img

# %%
Image.fromarray(draw_boxes('cows_images_185.jpg'))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-0c6c75fa7602> in <module>
# ----> 1 Image.fromarray(draw_boxes('cows_images_185.jpg'))
#
# <ipython-input-4-a84855093e5a> in draw_boxes(image_name)
#       2     selected_value = train_labels[train_labels.filename == image_name]
#       3     img = cv2.imread('raw_images/{}'.format(image_name))
# ----> 4     img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#       5     for index, row in selected_value.iterrows():
#       6         img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 3)
#
# error: OpenCV(4.1.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
Image.fromarray(draw_boxes('BLF1084.jpg'))
# Out:
# <PIL.Image.Image image mode=RGB size=531x354 at 0x7F34690B90B8>
